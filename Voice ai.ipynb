# %% [markdown]
# <a href="https://colab.research.google.com/github/AyushGautam390390/Voice-AI-Backend/blob/main/Voice%20ai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Audio1 = "/content/drive/MyDrive/Audio1.m4a"

# %%
Audio2 = "/content/drive/MyDrive/Audio2.m4a"

# %%
# !pip install openai-whisper
# !apt update
# !apt install ffmpeg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 41.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.3/188.3 MB 5.4 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=a644a9274e533661290ac29e7a0f2b0e245c474a863dbe0e732a2ad68b4ee897
#   Stored in directory: /root/.cache/pip/wheels/61/d2/20/09ec9bef734d126cba375b15898010b6cc28578d8afdde5869
# Successfully built openai-whisper
# ...
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# ...

# %%
import whisper

model = whisper.load_model("base")

result = model.transcribe("/content/drive/MyDrive/Audio1.m4a")

print(result["text"])
# Out:
# 100%|████████████████████████████████████████| 139M/139M [00:01<00:00, 140MiB/s]
# /usr/local/lib/python3.12/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# ...

# %%
import whisper

model = whisper.load_model("base")

result2 = model.transcribe(Audio2)

print(result2["text"])
# Out:
# /usr/local/lib/python3.12/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# ...

# %%
transcript = result["text"]

prompt = f"""
User said: {transcript}

Respond like a helpful assistant.
"""

print(prompt)
# Out:
# User said:  Heard about RLC AUC but not sure what it tells you. Let me explain you in just 60 seconds. RLC AUC stands for receiver operating characteristics, area under the curve. It goes from 0 to 1 that shows how well your model can separate classes like positive versus negative, spam versus not spam. AUC of 0.5, that's random guessing. Your model is just flipping a coin. AUC of 1, perfect. Your model separate classes with zero mistakes. AUC above 0.8, that's usually considered pretty strong. Below 0.5, your model got some work to do. RLC AUC super useful when your data is imbalanced. Like if you have way more safe emails than spam emails, unlike simple accuracy, RLC AUC isn't just fooled by class imbalance. The higher the AUC, the better your model is as separating classes across all threshold. Not just one. If you want more practical air tips like this, hit the like, drop a comment and don't forget to subscribe.
#
# Respond like a helpful assistant.

# %%
# !pip install gTTS
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 10.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.3.1
#     Uninstalling click-8.3.1:
#       Successfully uninstalled click-8.3.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# typer 0.24.1 requires click>=8.2.1, but you have click 8.1.8 which is incompatible.
# ...

# %%
from gtts import gTTS

response_text = "Heard about RLC AUC but not sure what it tells you."

tts = gTTS(response_text)
tts.save("response.mp3")

# %%
from fastapi import FastAPI, UploadFile
import whisper

app = FastAPI()
model = whisper.load_model("base")

@app.post("/voice-input")
async def voice_input(file: UploadFile):

    with open("audio.mp3", "wb") as f:
        f.write(await file.read())

    result = model.transcribe("audio.mp3")
    text = result["text"]

    return {"transcript": text}

# %%
pip install fastapi uvicorn openai-whisper gtts python-multipart

# %%
from fastapi import FastAPI, UploadFile, File
import whisper
from gtts import gTTS
import shutil

app = FastAPI()

# Load Whisper model once
model = whisper.load_model("base")


def fake_llm_response(text: str):
    """
    Simple placeholder for LLM.
    Replace with OpenAI / Groq later.
    """
    return f"You said: {text}. That sounds interesting!"


@app.post("/voice-input")
async def voice_input(file: UploadFile = File(...)):

    # Save uploaded audio
    with open("input_audio.mp3", "wb") as buffer:
        shutil.copyfileobj(file.file, buffer)

    # 1️⃣ Speech-to-Text
    result = model.transcribe("input_audio.mp3")
    transcript = result["text"]

    # 2️⃣ LLM Processing
    response_text = fake_llm_response(transcript)

    # 3️⃣ Text-to-Speech
    tts = gTTS(response_text)
    tts.save("response_audio.mp3")

    return {
        "transcript": transcript,
        "response_text": response_text,
        "audio_file": "response_audio.mp3"
    }
